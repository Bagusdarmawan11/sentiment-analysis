# %% [markdown]
# # Scraping Ulasan Aplikasi Twitter dari Google Play Store
#
# Notebook ini digunakan untuk melakukan proses pengambilan data ulasan aplikasi **Twitter** dari Google Play Store menggunakan library `google-play-scraper`. Data akan diberi label sentimen berdasarkan rating dan dibersihkan untuk digunakan dalam pelatihan model Machine Learning.
#
# ## Langkah-langkah:
# - Instalasi library
# - Scraping data ulasan
# - Menyimpan data ke CSV
# - Pemberian label sentimen (positif, netral, negatif)
# - Pembersihan teks (preprocessing)

# %%
# Install library
# !pip install google-play-scraper
# Out:
# Requirement already satisfied: google-play-scraper in /usr/local/lib/python3.11/dist-packages (1.2.7)

# %%
# Import library
from google_play_scraper import reviews, Sort
import pandas as pd
import re

# %%
# Set variabel
app_id = 'com.twitter.android'
total_reviews = 10000
batch_size = 100
all_reviews = []

# %%
# Scraping loop
for i in range(0, total_reviews, batch_size):
    print(f"Scraping {i + 1} - {i + batch_size} ...")
    result, _ = reviews(
        app_id,
        lang='id',
        country='id',
        sort=Sort.NEWEST,
        count=batch_size,
        filter_score_with=None
    )
    all_reviews.extend(result)
# Out:
# Scraping 1 - 100 ...
# Scraping 101 - 200 ...
# Scraping 201 - 300 ...
# Scraping 301 - 400 ...
# Scraping 401 - 500 ...
# Scraping 501 - 600 ...
# Scraping 601 - 700 ...
# Scraping 701 - 800 ...
# Scraping 801 - 900 ...
# Scraping 901 - 1000 ...
# Scraping 1001 - 1100 ...
# Scraping 1101 - 1200 ...
# Scraping 1201 - 1300 ...
# Scraping 1301 - 1400 ...
# Scraping 1401 - 1500 ...
# Scraping 1501 - 1600 ...
# Scraping 1601 - 1700 ...
# Scraping 1701 - 1800 ...
# Scraping 1801 - 1900 ...
# Scraping 1901 - 2000 ...
# Scraping 2001 - 2100 ...
# Scraping 2101 - 2200 ...
# Scraping 2201 - 2300 ...
# Scraping 2301 - 2400 ...
# Scraping 2401 - 2500 ...
# Scraping 2501 - 2600 ...
# Scraping 2601 - 2700 ...
# Scraping 2701 - 2800 ...
# Scraping 2801 - 2900 ...
# Scraping 2901 - 3000 ...
# Scraping 3001 - 3100 ...
# Scraping 3101 - 3200 ...
# Scraping 3201 - 3300 ...
# Scraping 3301 - 3400 ...
# Scraping 3401 - 3500 ...
# Scraping 3501 - 3600 ...
# Scraping 3601 - 3700 ...
# Scraping 3701 - 3800 ...
# Scraping 3801 - 3900 ...
# Scraping 3901 - 4000 ...
# Scraping 4001 - 4100 ...
# Scraping 4101 - 4200 ...
# Scraping 4201 - 4300 ...
# Scraping 4301 - 4400 ...
# Scraping 4401 - 4500 ...
# Scraping 4501 - 4600 ...
# Scraping 4601 - 4700 ...
# Scraping 4701 - 4800 ...
# Scraping 4801 - 4900 ...
# Scraping 4901 - 5000 ...
# Scraping 5001 - 5100 ...
# Scraping 5101 - 5200 ...
# Scraping 5201 - 5300 ...
# Scraping 5301 - 5400 ...
# Scraping 5401 - 5500 ...
# Scraping 5501 - 5600 ...
# Scraping 5601 - 5700 ...
# Scraping 5701 - 5800 ...
# Scraping 5801 - 5900 ...
# Scraping 5901 - 6000 ...
# Scraping 6001 - 6100 ...
# Scraping 6101 - 6200 ...
# Scraping 6201 - 6300 ...
# Scraping 6301 - 6400 ...
# Scraping 6401 - 6500 ...
# Scraping 6501 - 6600 ...
# Scraping 6601 - 6700 ...
# Scraping 6701 - 6800 ...
# Scraping 6801 - 6900 ...
# Scraping 6901 - 7000 ...
# Scraping 7001 - 7100 ...
# Scraping 7101 - 7200 ...
# Scraping 7201 - 7300 ...
# Scraping 7301 - 7400 ...
# Scraping 7401 - 7500 ...
# Scraping 7501 - 7600 ...
# Scraping 7601 - 7700 ...
# Scraping 7701 - 7800 ...
# Scraping 7801 - 7900 ...
# Scraping 7901 - 8000 ...
# Scraping 8001 - 8100 ...
# Scraping 8101 - 8200 ...
# Scraping 8201 - 8300 ...
# Scraping 8301 - 8400 ...
# Scraping 8401 - 8500 ...
# Scraping 8501 - 8600 ...
# Scraping 8601 - 8700 ...
# Scraping 8701 - 8800 ...
# Scraping 8801 - 8900 ...
# Scraping 8901 - 9000 ...
# Scraping 9001 - 9100 ...
# Scraping 9101 - 9200 ...
# Scraping 9201 - 9300 ...
# Scraping 9301 - 9400 ...
# Scraping 9401 - 9500 ...
# Scraping 9501 - 9600 ...
# Scraping 9601 - 9700 ...
# Scraping 9701 - 9800 ...
# Scraping 9801 - 9900 ...
# Scraping 9901 - 10000 ...

# %%
# Simpan ke DataFrame
df = pd.DataFrame(all_reviews)[['userName', 'content', 'score']]

# %%
# Labeling sentimen
def get_sentiment(score):
    if score <= 2:
        return 'negatif'
    elif score == 3:
        return 'netral'
    else:
        return 'positif'

df['label'] = df['score'].apply(get_sentiment)

# %%
# Preprocessing teks ulasan
def clean_text(text):
    text = text.lower()
    text = re.sub(r'http\S+', '', text)        # hapus URL
    text = re.sub(r'@\w+', '', text)           # hapus mention
    text = re.sub(r'#\w+', '', text)           # hapus hashtag
    text = re.sub(r'[^a-zA-Z\s]', '', text)    # hapus karakter selain huruf
    text = re.sub(r'\s+', ' ', text).strip()   # hapus spasi berlebih
    return text

df['clean_content'] = df['content'].apply(clean_text)

# Tampilkan hasil
df[['content', 'clean_content', 'score', 'label']].head()
# Out:
#                                              content  \
# 0                                              keren
# 1                                hidup yg terpeedaya
# 2                           Twitter skrng jlek skli,
# 3      udh di update tp pas dibuka ga bisa di scroll
# 4  gua masuk ke akun gua sendiri kenapa di kira a...
#
#                                        clean_content  score    label
# 0                                              keren      5  positif
# 1                                hidup yg terpeedaya      1  negatif
# 2                            twitter skrng jlek skli      5  positif
# 3      udh di update tp pas dibuka ga bisa di scroll      2  negatif
# 4  gua masuk ke akun gua sendiri kenapa di kira a...      1  negatif

# %%
# Simpan hasil akhir
df.to_csv('twitter_data_scraping.csv', index=False)
print("✅ Done! Total data scraped:", len(df))
# Out:
# ✅ Done! Total data scraped: 10000
